# %% [markdown]
# <a href="https://colab.research.google.com/github/qcatorres-cloud/CPE-009B-ObjectOrientedProgramming2/blob/main/Hands_On_Activity_0_3_(try_except)_TORRES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def input_nums_only(): #defines the input_nums_only function

 while True: #creates an endless loop if you don't type integers which executes the function again and again
  try: #uses the try for the ValueError when you input other data types instead of integers
   x = int(input("Enter the First Number: ")) #input the first number which is variable x and is in integer data type.
   y = int(input("Enter the Second Number: ")) #input the second number which is variable y and is in integer data type.
   return x, y #exits the function leaving the values inside the function
  except ValueError: #uses the except functions if the input is not an integer
   print("Need to input integers!") #prints a warning sign for you to input integers


def safe_cal(x, y, oprtr): #defines the safe_cal function
  try: #uses the "try" to test the operators if there are errors
    if oprtr == "+": #if you input + operator,
      return x + y #then it return the formula x + y
    elif oprtr == "-": #if you input - operator,
      return x - y #then it return the formula x - y
    elif oprtr == "*": #if you input * operator,
      return x * y #then it return the formula x * y
    elif oprtr == "/": #if you input / operator,
      return x / y #then it return the formula x / y
    else: #condition if you don't use the right type of operator,
      return "Invalid Use of Operator" #then it will return "Invalid use of Operator"
  except ZeroDivisionError: #uses the "except" for ZeroDivisionError if the y value is Zero
    return "Cannot Divide to Zero" #returns the result "Cannot Divide to Zero"

def main(): #defines the main function
    x, y = input_nums_only() #gets the data from the data that are stored at the input_nums_only function
    oprtr = input("Enter the desired operator(+,-,*,/): ") #User's Input on which operator they want to use
    result = safe_cal(x, y, oprtr) #gets the result from the operators from the safe_calculator and by the use of the values stored in input_nums_only function

    try: #uses the "try" to test if the results have errors
        print(f"The result of the calculations is: {result:.2f}") #displays the results that are formatted for numbers
    except ValueError: #uses the except if the inputted values have errors like invalid operator
        print(f"The result of the calculations is: {result}") #displays the results (error type of operators) as is

main() #executes the main code
# Out:
# Enter the First Number: W
# Need to input integers!
# Enter the First Number: A
# Need to input integers!
# Enter the First Number: 2.00
# Need to input integers!
# Enter the First Number: 3.00
# Need to input integers!
# Enter the First Number: Yes
# Need to input integers!
# Enter the First Number: 2
# Enter the Second Number: 5
# Enter the desired operator(+,-,*,/): /
# The result of the calculations is: 0.40
