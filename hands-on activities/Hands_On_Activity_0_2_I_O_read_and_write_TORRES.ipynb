# %% [markdown]
# <a href="https://colab.research.google.com/github/qcatorres-cloud/CPE-009B-ObjectOrientedProgramming2/blob/main/Hands_On_Activity_0_2_I_O_read_and_write_TORRES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a program in python that accepts input from the user (Basic information) and save to a text file
def user_input():

  name = input("Enter your name: ") #creating a user input for the name in the txt file
  age = int(input("Enter your age: ")) #creating a user input for the age in the txt file (int because Age is a number)
  gender = input("Enter your gender: ") #creating a user input for the gender in the txt file
  email = input("Enter your email: ") #creating a user input for the email in the txt file
  return name, age, gender, email
#
def write_file(filename, name, age, gender, email):
 with open(filename, "w") as f: #opens the file
  f.write(name + "\n") #writing the inputted name for the txt file
  f.write(f"{age} \n") #writing the inputted age for the txt file
  f.write(gender + "\n") #writing the inputted gender for the txt file
  f.write(email + "\n") #writing the inputted email for the txt file

def read_file(filename):
  return (f.read()) #reads the file

def print_info(filename):
  with open(filename, "r") as f: #opens the file
   print(f.read()) #displays the output of the file

def main():
  target_file = "CTorres.txt" #choose the target txt file
  name, age, gender, email = user_input() #gets the info from the user_input() function
  write_file(target_file, name, age, gender, email) #calls the write_file function
  print_info(target_file) #calls the print_info function

main() #execute the main code
# Out:
# Enter your name: Carl Andrei D. Torres
# Enter your age: 19
# Enter your gender: Male
# Enter your email: qcatorres@tip.edu.ph
# Carl Andrei D. Torres
# 19
# Male
# qcatorres@tip.edu.ph
